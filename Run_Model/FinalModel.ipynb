# %%
# Apply Imports

import tensorflow as tf
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from mpl_toolkits.mplot3d import Axes3D

# %%
# Load and preprocess data
def load_data(file_path):
    # Load data from CSV file
    url = 'https://raw.githubusercontent.com/Okazeil/ML_Final_project/main/pm_sensor_data_converted.csv'
    data = pd.read_csv(url)

    # Split data into features and labels
    X = data.iloc[:, :-1].values
    y = data.iloc[:, -1].values

    return X, y

# Define the model
def build_tuned_model(input_shape, n_layers=2, n_neurons=64, learning_rate=0.001):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(n_neurons, activation='relu', input_shape=(input_shape,)))
    for _ in range(1, n_layers):
        model.add(tf.keras.layers.Dense(n_neurons, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Load data Universal
file_path = 'https://raw.githubusercontent.com/Okazeil/ML_Final_project/main/pm_sensor_data_converted.csv'
X, y = load_data(file_path)

# %%
# Debugging: Print the shape of X and y
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# Scale features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Adjust these parameters based on your hyperparameter tuning results
n_layers = 3
n_neurons = 128
learning_rate = 0.01

# Build and train the model
model = build_tuned_model(input_shape=X_train.shape[1], n_layers=n_layers, n_neurons=n_neurons, learning_rate=learning_rate)
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

joblib.dump(scaler, 'scaler.pkl')

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Accuracy: {accuracy}")

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()
# Out:
# Shape of X: (91, 3)
# Shape of y: (91,)
# Epoch 1/100
# c:\Users\okaze\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.5565 - loss: 0.6724 - val_accuracy: 0.8667 - val_loss: 0.5324
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8660 - loss: 0.5193 - val_accuracy: 0.8667 - val_loss: 0.3857
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8660 - loss: 0.4255 - val_accuracy: 0.9333 - val_loss: 0.1871
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9441 - loss: 0.3219 - val_accuracy: 1.0000 - val_loss: 0.1026
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9441 - loss: 0.2287 - val_accuracy: 1.0000 - val_loss: 0.0546
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9337 - loss: 0.1778 - val_accuracy: 1.0000 - val_loss: 0.0400
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9883 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0199
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9883 - loss: 0.0387 - val_accuracy: 0.9333 - val_loss: 0.0898
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0444 - val_accuracy: 0.9333 - val_loss: 0.0850
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.9333 - val_loss: 0.0662
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9333 - val_loss: 0.1000
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9333 - val_loss: 0.2042
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9333 - val_loss: 0.1335
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9333 - val_loss: 0.0745
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9333 - val_loss: 0.1064
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 3.6575e-04 - val_accuracy: 0.9333 - val_loss: 0.1575
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 3.0902e-04 - val_accuracy: 0.9333 - val_loss: 0.2334
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 1.5429e-04 - val_accuracy: 0.9333 - val_loss: 0.3022
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 1.3980e-04 - val_accuracy: 0.9333 - val_loss: 0.3583
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 1.3564e-04 - val_accuracy: 0.9333 - val_loss: 0.3931
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 1.0622e-04 - val_accuracy: 0.9333 - val_loss: 0.4120
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 8.1603e-05 - val_accuracy: 0.9333 - val_loss: 0.4137
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 8.9081e-05 - val_accuracy: 0.9333 - val_loss: 0.4021
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 5.3944e-05 - val_accuracy: 0.9333 - val_loss: 0.3873
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 4.1507e-05 - val_accuracy: 0.9333 - val_loss: 0.3730
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 2.7864e-05 - val_accuracy: 0.9333 - val_loss: 0.3610
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 2.7874e-05 - val_accuracy: 0.9333 - val_loss: 0.3500
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 3.0857e-05 - val_accuracy: 0.9333 - val_loss: 0.3432
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 2.9918e-05 - val_accuracy: 0.9333 - val_loss: 0.3395
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 2.2795e-05 - val_accuracy: 0.9333 - val_loss: 0.3383
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 2.2115e-05 - val_accuracy: 0.9333 - val_loss: 0.3405
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.8229e-05 - val_accuracy: 0.9333 - val_loss: 0.3454
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 1.7195e-05 - val_accuracy: 0.9333 - val_loss: 0.3515
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 1.1341e-05 - val_accuracy: 0.9333 - val_loss: 0.3581
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 1.7876e-05 - val_accuracy: 0.9333 - val_loss: 0.3664
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 1.1704e-05 - val_accuracy: 0.9333 - val_loss: 0.3730
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 1.5198e-05 - val_accuracy: 0.9333 - val_loss: 0.3809
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 1.1942e-05 - val_accuracy: 0.9333 - val_loss: 0.3874
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 1.5257e-05 - val_accuracy: 0.9333 - val_loss: 0.3930
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 1.2435e-05 - val_accuracy: 0.9333 - val_loss: 0.3982
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 1.0153e-05 - val_accuracy: 0.9333 - val_loss: 0.4014
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.1459e-05 - val_accuracy: 0.9333 - val_loss: 0.4052
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 1.3504e-05 - val_accuracy: 0.9333 - val_loss: 0.4075
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 9.9279e-06 - val_accuracy: 0.9333 - val_loss: 0.4096
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 1.1846e-05 - val_accuracy: 0.9333 - val_loss: 0.4105
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 9.6559e-06 - val_accuracy: 0.9333 - val_loss: 0.4109
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 1.0364e-05 - val_accuracy: 0.9333 - val_loss: 0.4114
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 9.8509e-06 - val_accuracy: 0.9333 - val_loss: 0.4119
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 1.0038e-05 - val_accuracy: 0.9333 - val_loss: 0.4128
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 8.8289e-06 - val_accuracy: 0.9333 - val_loss: 0.4130
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 1.1239e-05 - val_accuracy: 0.9333 - val_loss: 0.4123
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 7.2546e-06 - val_accuracy: 0.9333 - val_loss: 0.4117
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 6.5239e-06 - val_accuracy: 0.9333 - val_loss: 0.4109
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 8.9771e-06 - val_accuracy: 0.9333 - val_loss: 0.4099
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 8.3429e-06 - val_accuracy: 0.9333 - val_loss: 0.4090
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 9.2212e-06 - val_accuracy: 0.9333 - val_loss: 0.4092
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 7.9712e-06 - val_accuracy: 0.9333 - val_loss: 0.4083
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 1.0627e-05 - val_accuracy: 0.9333 - val_loss: 0.4081
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 9.8395e-06 - val_accuracy: 0.9333 - val_loss: 0.4078
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 8.6773e-06 - val_accuracy: 0.9333 - val_loss: 0.4080
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 7.9405e-06 - val_accuracy: 0.9333 - val_loss: 0.4077
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 7.9666e-06 - val_accuracy: 0.9333 - val_loss: 0.4072
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 8.4854e-06 - val_accuracy: 0.9333 - val_loss: 0.4065
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 9.9549e-06 - val_accuracy: 0.9333 - val_loss: 0.4055
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 8.0411e-06 - val_accuracy: 0.9333 - val_loss: 0.4049
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 9.8215e-06 - val_accuracy: 0.9333 - val_loss: 0.4039
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 5.8854e-06 - val_accuracy: 0.9333 - val_loss: 0.4031
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 7.2680e-06 - val_accuracy: 0.9333 - val_loss: 0.4029
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 7.3771e-06 - val_accuracy: 0.9333 - val_loss: 0.4025
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 7.7114e-06 - val_accuracy: 0.9333 - val_loss: 0.4023
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 8.4803e-06 - val_accuracy: 0.9333 - val_loss: 0.4016
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 5.4567e-06 - val_accuracy: 0.9333 - val_loss: 0.4013
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 7.6830e-06 - val_accuracy: 0.9333 - val_loss: 0.4015
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 7.5267e-06 - val_accuracy: 0.9333 - val_loss: 0.4016
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 5.4157e-06 - val_accuracy: 0.9333 - val_loss: 0.4013
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 7.1876e-06 - val_accuracy: 0.9333 - val_loss: 0.4016
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 5.9538e-06 - val_accuracy: 0.9333 - val_loss: 0.4011
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 4.9670e-06 - val_accuracy: 0.9333 - val_loss: 0.4015
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 6.7157e-06 - val_accuracy: 0.9333 - val_loss: 0.4023
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 5.0914e-06 - val_accuracy: 0.9333 - val_loss: 0.4027
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 6.5301e-06 - val_accuracy: 0.9333 - val_loss: 0.4034
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 4.3744e-06 - val_accuracy: 0.9333 - val_loss: 0.4037
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 7.3855e-06 - val_accuracy: 0.9333 - val_loss: 0.4042
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 4.6042e-06 - val_accuracy: 0.9333 - val_loss: 0.4048
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 7.8280e-06 - val_accuracy: 0.9333 - val_loss: 0.4053
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 7.3263e-06 - val_accuracy: 0.9333 - val_loss: 0.4058
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 4.5899e-06 - val_accuracy: 0.9333 - val_loss: 0.4063
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 5.3401e-06 - val_accuracy: 0.9333 - val_loss: 0.4065
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 7.1101e-06 - val_accuracy: 0.9333 - val_loss: 0.4072
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 6.1453e-06 - val_accuracy: 0.9333 - val_loss: 0.4084
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 6.1379e-06 - val_accuracy: 0.9333 - val_loss: 0.4090
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 5.6105e-06 - val_accuracy: 0.9333 - val_loss: 0.4093
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 5.0164e-06 - val_accuracy: 0.9333 - val_loss: 0.4088
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 6.5370e-06 - val_accuracy: 0.9333 - val_loss: 0.4089
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 5.6337e-06 - val_accuracy: 0.9333 - val_loss: 0.4095
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 4.0361e-06 - val_accuracy: 0.9333 - val_loss: 0.4093
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 5.3380e-06 - val_accuracy: 0.9333 - val_loss: 0.4094
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 4.7306e-06 - val_accuracy: 0.9333 - val_loss: 0.4088
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 6.5800e-06 - val_accuracy: 0.9333 - val_loss: 0.4089
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 6.3426e-06 - val_accuracy: 0.9333 - val_loss: 0.4092
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 4.6364e-06 - val_accuracy: 0.9333 - val_loss: 0.4090
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 3.4802e-06 - val_accuracy: 0.9333 - val_loss: 0.4095
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 6.2084e-06 - val_accuracy: 0.9333 - val_loss: 0.4101
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 6.2755e-06 - val_accuracy: 0.9333 - val_loss: 0.4105
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 5.9316e-06 - val_accuracy: 0.9333 - val_loss: 0.4109
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 3.3937e-06 - val_accuracy: 0.9333 - val_loss: 0.4112
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 4.6308e-06 - val_accuracy: 0.9333 - val_loss: 0.4113
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 3.5874e-06 - val_accuracy: 0.9333 - val_loss: 0.4119
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 5.8086e-06 - val_accuracy: 0.9333 - val_loss: 0.4125
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 5.5649e-06 - val_accuracy: 0.9333 - val_loss: 0.4128
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 3.2656e-06 - val_accuracy: 0.9333 - val_loss: 0.4131
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 5.7412e-06 - val_accuracy: 0.9333 - val_loss: 0.4135
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 4.7387e-06 - val_accuracy: 0.9333 - val_loss: 0.4140
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 5.4082e-06 - val_accuracy: 0.9333 - val_loss: 0.4139
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 3.0909e-06 - val_accuracy: 0.9333 - val_loss: 0.4137
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 3.8353e-06 - val_accuracy: 0.9333 - val_loss: 0.4133
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 4.3128e-06 - val_accuracy: 0.9333 - val_loss: 0.4137
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 5.2418e-06 - val_accuracy: 0.9333 - val_loss: 0.4138
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 2.9914e-06 - val_accuracy: 0.9333 - val_loss: 0.4137
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 3.8720e-06 - val_accuracy: 0.9333 - val_loss: 0.4135
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 2.9728e-06 - val_accuracy: 0.9333 - val_loss: 0.4138
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 4.2927e-06 - val_accuracy: 0.9333 - val_loss: 0.4143
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 2.9474e-06 - val_accuracy: 0.9333 - val_loss: 0.4142
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 4.6789e-06 - val_accuracy: 0.9333 - val_loss: 0.4141
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 4.7629e-06 - val_accuracy: 0.9333 - val_loss: 0.4140
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 3.9765e-06 - val_accuracy: 0.9333 - val_loss: 0.4143
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 4.4572e-06 - val_accuracy: 0.9333 - val_loss: 0.4141
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 2.7028e-06 - val_accuracy: 0.9333 - val_loss: 0.4139
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 2.6828e-06 - val_accuracy: 0.9333 - val_loss: 0.4138
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 3.6027e-06 - val_accuracy: 0.9333 - val_loss: 0.4136
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 2.6226e-06 - val_accuracy: 0.9333 - val_loss: 0.4140
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 3.4072e-06 - val_accuracy: 0.9333 - val_loss: 0.4143
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 3.2553e-06 - val_accuracy: 0.9333 - val_loss: 0.4147
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 3.7044e-06 - val_accuracy: 0.9333 - val_loss: 0.4158
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 3.4219e-06 - val_accuracy: 0.9333 - val_loss: 0.4160
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 2.4213e-06 - val_accuracy: 0.9333 - val_loss: 0.4166
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 4.1574e-06 - val_accuracy: 0.9333 - val_loss: 0.4172
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 4.0508e-06 - val_accuracy: 0.9333 - val_loss: 0.4177
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 4.1733e-06 - val_accuracy: 0.9333 - val_loss: 0.4182
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 3.3226e-06 - val_accuracy: 0.9333 - val_loss: 0.4187
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 4.1339e-06 - val_accuracy: 0.9333 - val_loss: 0.4188
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 3.7635e-06 - val_accuracy: 0.9333 - val_loss: 0.4188
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 3.7820e-06 - val_accuracy: 0.9333 - val_loss: 0.4188
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 3.7417e-06 - val_accuracy: 0.9333 - val_loss: 0.4187
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 3.1027e-06 - val_accuracy: 0.9333 - val_loss: 0.4189
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 2.7899e-06 - val_accuracy: 0.9333 - val_loss: 0.4183
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 2.0948e-06 - val_accuracy: 0.9333 - val_loss: 0.4183
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.8329e-06 - val_accuracy: 0.9333 - val_loss: 0.4181
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 2.9388e-06 - val_accuracy: 0.9333 - val_loss: 0.4187
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 3.7459e-06 - val_accuracy: 0.9333 - val_loss: 0.4188
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 2.6985e-06 - val_accuracy: 0.9333 - val_loss: 0.4186
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 3.0697e-06 - val_accuracy: 0.9333 - val_loss: 0.4193
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 2.6975e-06 - val_accuracy: 0.9333 - val_loss: 0.4191
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 3.5533e-06 - val_accuracy: 0.9333 - val_loss: 0.4196
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 2.6549e-06 - val_accuracy: 0.9333 - val_loss: 0.4198
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 3.2883e-06 - val_accuracy: 0.9333 - val_loss: 0.4204
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 2.5732e-06 - val_accuracy: 0.9333 - val_loss: 0.4206
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 1.9734e-06 - val_accuracy: 0.9333 - val_loss: 0.4213
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 2.7192e-06 - val_accuracy: 0.9333 - val_loss: 0.4222
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 3.2614e-06 - val_accuracy: 0.9333 - val_loss: 0.4225
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 2.4486e-06 - val_accuracy: 0.9333 - val_loss: 0.4225
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 2.5317e-06 - val_accuracy: 0.9333 - val_loss: 0.4232
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 3.2371e-06 - val_accuracy: 0.9333 - val_loss: 0.4233
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 3.1468e-06 - val_accuracy: 0.9333 - val_loss: 0.4234
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 2.9659e-06 - val_accuracy: 0.9333 - val_loss: 0.4234
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 2.9705e-06 - val_accuracy: 0.9333 - val_loss: 0.4234
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 2.3206e-06 - val_accuracy: 0.9333 - val_loss: 0.4232
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 2.3889e-06 - val_accuracy: 0.9333 - val_loss: 0.4232
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.8822e-06 - val_accuracy: 0.9333 - val_loss: 0.4236
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 2.3826e-06 - val_accuracy: 0.9333 - val_loss: 0.4237
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 2.2516e-06 - val_accuracy: 0.9333 - val_loss: 0.4239
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 2.8860e-06 - val_accuracy: 0.9333 - val_loss: 0.4247
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 2.7202e-06 - val_accuracy: 0.9333 - val_loss: 0.4252
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 2.1592e-06 - val_accuracy: 0.9333 - val_loss: 0.4254
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 2.1437e-06 - val_accuracy: 0.9333 - val_loss: 0.4257
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 2.2381e-06 - val_accuracy: 0.9333 - val_loss: 0.4261
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 2.0967e-06 - val_accuracy: 0.9333 - val_loss: 0.4267
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 2.6420e-06 - val_accuracy: 0.9333 - val_loss: 0.4275
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 2.2822e-06 - val_accuracy: 0.9333 - val_loss: 0.4283
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 2.1368e-06 - val_accuracy: 0.9333 - val_loss: 0.4287
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 2.1502e-06 - val_accuracy: 0.9333 - val_loss: 0.4283
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 2.0435e-06 - val_accuracy: 0.9333 - val_loss: 0.4281
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 2.1161e-06 - val_accuracy: 0.9333 - val_loss: 0.4285
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 2.0450e-06 - val_accuracy: 0.9333 - val_loss: 0.4282
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 2.0334e-06 - val_accuracy: 0.9333 - val_loss: 0.4281
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 1.4142e-06 - val_accuracy: 0.9333 - val_loss: 0.4284
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 2.0239e-06 - val_accuracy: 0.9333 - val_loss: 0.4289
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 1.9753e-06 - val_accuracy: 0.9333 - val_loss: 0.4289
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.9960e-06 - val_accuracy: 0.9333 - val_loss: 0.4288
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 2.3808e-06 - val_accuracy: 0.9333 - val_loss: 0.4282
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 2.3088e-06 - val_accuracy: 0.9333 - val_loss: 0.4278
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 1.4162e-06 - val_accuracy: 0.9333 - val_loss: 0.4274
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 1.3616e-06 - val_accuracy: 0.9333 - val_loss: 0.4271
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 1.4539e-06 - val_accuracy: 0.9333 - val_loss: 0.4269
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 2.1927e-06 - val_accuracy: 0.9333 - val_loss: 0.4268
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 1.4244e-06 - val_accuracy: 0.9333 - val_loss: 0.4268
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.7469e-06 - val_accuracy: 0.9333 - val_loss: 0.4265
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 2.2000e-06 - val_accuracy: 0.9333 - val_loss: 0.4268
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.6652e-06 - val_accuracy: 0.9333 - val_loss: 0.4269
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 2.1807e-06 - val_accuracy: 0.9333 - val_loss: 0.4273
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9474 - loss: 0.1283
# Accuracy: 0.9473684430122375

# %% [markdown]
# Here's an example of how you can create a 3D scatter plot of your data, with points color-coded based on their labels (working or not working):

# %%
# Load data again to get unscaled values for better visualization
X, y = load_data(file_path)

# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap='RdYlGn', marker='o')

# Labels and title
ax.set_xlabel('CPU1 Temperature')
ax.set_ylabel('CPU2 Temperature')
ax.set_zlabel('Average Fan Speed')
ax.set_title('3D Scatter Plot of Server Data')

# Colorbar
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Working Status (0: Not Working, 1: Working)')

plt.show()

# %% [markdown]
# Attempt to produce a user interaction

# %%
def predict_server_status(cpu1_temp, cpu2_temp, fan_speed, model, scaler):
    # Prepare the input data in the same format as the training data
    input_data = np.array([[cpu1_temp, cpu2_temp, fan_speed]])
    input_data_scaled = scaler.transform(input_data)

    # Make a prediction
    prediction = model.predict(input_data_scaled)
    status = 'Working' if prediction[0][0] > 0.5 else 'Not Working'
    return status

# Example usage
status = predict_server_status(39, 36, 5000, model, scaler)
print("Server Status:", status)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Server Status: Working

# %%
model.save('my_model.h5')

# Save the scaler
import joblib
joblib.dump(scaler, 'scaler.gz')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler.gz']

# %%
import tensorflow as tf
import joblib

# Load the TensorFlow model
model = tf.keras.models.load_model('my_model.h5')

# Load the scaler
scaler = joblib.load('scaler.gz')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import pandas as pd

# Load the data
data_df = pd.read_csv(file_path)

# Apply scaling
X_scaled = scaler.transform(data_df[['cpu1_temp', 'cpu2_temp', 'average_fan_speed']])
# Out:
# c:\Users\okaze\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(

# %%
# Make predictions
predictions = model.predict(X_scaled)

# Convert predictions to binary labels
predicted_labels = (predictions > 0.5).astype(int).flatten()
# Out:
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/stepWARNING:tensorflow:5 out of the last 255 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000258C1289EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 255 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000258C1289EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
from mpl_toolkits.mplot3d import Axes3D

# Selecting features for the plot
feature1 = 'cpu1_temp'
feature2 = 'cpu2_temp'
feature3 = 'average_fan_speed'

# Create a 3D scatter plot
plt.figure(figsize=(10, 8))
ax = plt.axes(projection='3d')

# Plotting data points with different colors based on predicted label
for label in [0, 1]:
    filtered_data = data_df[predicted_labels == label]
    ax.scatter(filtered_data[feature1], filtered_data[feature2], filtered_data[feature3], label=f'Predicted: {label}')

ax.set_xlabel(feature1)
ax.set_ylabel(feature2)
ax.set_zlabel(feature3)
ax.legend()
ax.set_title('Model Predictions in 3D')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Actual labels
actual_labels = data_df['working']

# Identify misclassified points
misclassified = predicted_labels != actual_labels

# Selecting features for the plot
feature1 = 'cpu1_temp'
feature2 = 'cpu2_temp'
feature3 = 'average_fan_speed'

# Create a 3D scatter plot
plt.figure(figsize=(12, 10))
ax = plt.axes(projection='3d')

# Plotting correctly classified points
for label in [0, 1]:
    filtered_data = data_df[(predicted_labels == label) & ~misclassified]
    ax.scatter(filtered_data[feature1], filtered_data[feature2], filtered_data[feature3], label=f'Correctly Predicted: {label}')

# Highlighting misclassified points
ax.scatter(data_df.loc[misclassified, feature1],
           data_df.loc[misclassified, feature2],
           data_df.loc[misclassified, feature3],
           color='red', marker='x', label='Misclassified', s=100)

ax.set_xlabel(feature1)
ax.set_ylabel(feature2)
ax.set_zlabel(feature3)
ax.legend()
ax.set_title('Model Predictions with Misclassified Points Highlighted')
plt.show()

# %%
# Calculate the number of misclassifications
num_misclassified = sum(misclassified)

# Print the number of misclassifications
print(f"Number of Misclassified Points: {num_misclassified}")
# Out:
# Number of Misclassified Points: 2

# %% [markdown]
# 2D Visualisation of Decision Boundary

# %%
import numpy as np

# Feature ranges - you may need to adjust these based on your data
feature1_range = np.linspace(data_df[feature1].min(), data_df[feature1].max(), 100)
feature2_range = np.linspace(data_df[feature2].min(), data_df[feature2].max(), 100)

# Create a mesh grid
xx, yy = np.meshgrid(feature1_range, feature2_range)

# Set the constant value for the third feature (e.g., the mean)
feature3_constant = data_df[feature3].mean()

# Predict for each point in the mesh grid
grid_predictions = model.predict(scaler.transform(np.c_[xx.ravel(), yy.ravel(), np.full_like(xx.ravel(), feature3_constant)]))
grid_predictions = grid_predictions.reshape(xx.shape)

# Plotting the decision boundary
plt.contourf(xx, yy, grid_predictions, alpha=0.8)
plt.scatter(data_df[feature1], data_df[feature2], c=data_df['working'], edgecolors='k', s=20)
plt.xlabel(feature1)
plt.ylabel(feature2)
plt.title('Decision Boundary with Feature3 = {:.2f}'.format(feature3_constant))
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# 3D Modelling:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
# Assuming you're using Keras, for example
from keras.models import load_model

# Load your dataset
data_df = pd.read_csv('https://raw.githubusercontent.com/Okazeil/ML_Final_project/main/pm_sensor_data_converted.csv')

# Assuming 'scaler' is your StandardScaler instance and 'model' is your trained model
scaler = joblib.load('scaler.gz')
model = tf.keras.models.load_model('my_model.h5')

# Determine min and max values for each feature from the dataset
min_cpu1_temp = 0
max_cpu1_temp = 80
min_cpu2_temp = 0
max_cpu2_temp = 80
min_average_fan_speed = 3000
max_average_fan_speed = data_df['average_fan_speed'].max()

# Define the actual ranges for your features based on the min and max values
feature1_range = np.linspace(min_cpu1_temp, max_cpu1_temp, 20)
feature2_range = np.linspace(min_cpu2_temp, max_cpu2_temp, 20)
feature3_range = np.linspace(min_average_fan_speed, max_average_fan_speed, 20)

# Generate a mesh grid for 3D plotting
xx, yy, zz = np.meshgrid(feature1_range, feature2_range, feature3_range)

# Flatten the grid to pass into the model for predictions
grid = np.vstack([xx.ravel(), yy.ravel(), zz.ravel()]).T

# Scale the grid
grid_scaled = scaler.transform(grid)

# Predict on the grid
probabilities = model.predict(grid_scaled)

# Reshape the predictions to fit the xx, yy, zz grid for 3D plotting
decision_values = probabilities.reshape(xx.shape)

# Visualization
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot the decision boundary
ax.scatter(xx.ravel(), yy.ravel(), zz.ravel(), c=decision_values.ravel(), cmap='RdYlGn', alpha=0.5)

ax.set_xlabel('CPU1 Temp')
ax.set_ylabel('CPU2 Temp')
ax.set_zlabel('Average Fan Speed')
plt.title('3D Decision Boundary Visualization Covering All Data Points')

plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
